# %%
import datasets
from datasets import load_dataset, Dataset

# fist start with trivia
datasets.config.DOWNLOADED_DATASETS_PATH = "/home/public/wjang/data/triviaqa-wiki"

triviaqa = load_dataset("trivia_qa", "unfiltered")
triviaqa
# Out:
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Downloading data: 100%|██████████| 633M/633M [00:16<00:00, 39.0MB/s]
# Downloading data files: 100%|██████████| 2/2 [00:17<00:00,  8.55s/it]
# Extracting data files: 100%|██████████| 2/2 [00:12<00:00,  6.28s/it]
# Extracting data files:   0%|          | 0/1 [07:34<?, ?it/s]03:13, 397.96 examples/s]
# Generating train split:  38%|███▊      | 32999/87622 [05:36<01:57, 464.39 examples/s]

# %%
triviaqa
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['question', 'question_id', 'question_source', 'entity_pages', 'search_results', 'answer'],
#         num_rows: 87622
#     })
#     validation: Dataset({
#         features: ['question', 'question_id', 'question_source', 'entity_pages', 'search_results', 'answer'],
#         num_rows: 11313
#     })
#     test: Dataset({
#         features: ['question', 'question_id', 'question_source', 'entity_pages', 'search_results', 'answer'],
#         num_rows: 10832
#     })
# })
